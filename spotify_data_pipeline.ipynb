# %%
# !pip install spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
# Authentication
client_credentials_manager = SpotifyClientCredentials(client_id = "72fd014779dd423b98cc127a0d555b84", client_secret="7f15033e5d5e492597ada6f07fb2db4f")

# %%
# Authorization
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link="https://open.spotify.com/playlist/6Qx1mpsEza6QzVguvmUhUQ"

# %%
playlist_uri= playlist_link.split("/")[-1]

# %%
data = sp.playlist_tracks(playlist_uri)

# %%
len(data['items'])
# Out:
# 100

# %%
data['items'][0]['track']['album']['id']
# Out:
# '6kj47h4a5ptQiZRYsihT1Y'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Missing Something'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2024-08-02'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 8

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/6kj47h4a5ptQiZRYsihT1Y'

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id': album_id, 'name': album_name, 'release_date': album_release_date,
                    'total_tracks':album_total_tracks,'url' :album_url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '6kj47h4a5ptQiZRYsihT1Y',
#   'name': 'Missing Something',
#   'release_date': '2024-08-02',
#   'total_tracks': 8,
#   'url': 'https://open.spotify.com/album/6kj47h4a5ptQiZRYsihT1Y'},
#  {'album_id': '5NhFIWsZFIOACwnsba6Opj',
#   'name': 'Belaad',
#   'release_date': '2024-02-03',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5NhFIWsZFIOACwnsba6Opj'},
#  {'album_id': '0Ft9mzyrJfw4XvitON7gMx',
#   'name': 'Doone Koochooloo',
#   'release_date': '2024-04-02',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/0Ft9mzyrJfw4XvitON7gMx'},
#  {'album_id': '7eQZeSPrFTIMVKKFCTjwO7',
#   'name': 'Shabhaye Tehran',
#   'release_date': '2024-07-26',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7eQZeSPrFTIMVKKFCTjwO7'},
#  {'album_id': '12zV0xfge3v6Fh6p0cxm4T',
#   'name': 'TNTV',
#   'release_date': '2024-07-11',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/12zV0xfge3v6Fh6p0cxm4T'},
# ...

# %%
data['items'][0]['track']['artists'][0]['id']
# Out:
# '2CPDwyokR2lgqu0yNGe2cU'

# %%
artist_list = []
for row in data['items']:
    for key,value in row.items():
        if key == "track":
            for artist in value['artists']:
                artist_dict = {'artist_id':artist['id'],'artist_name':artist['name'],'external_url':artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '2CPDwyokR2lgqu0yNGe2cU',
#   'artist_name': 'Asal',
#   'external_url': 'https://api.spotify.com/v1/artists/2CPDwyokR2lgqu0yNGe2cU'},
#  {'artist_id': '45YMrIBH74j8e2wNlRSSdK',
#   'artist_name': 'Hiphopologist',
#   'external_url': 'https://api.spotify.com/v1/artists/45YMrIBH74j8e2wNlRSSdK'},
#  {'artist_id': '1sKlyO3CCEvjeTN6Uck39S',
#   'artist_name': 'Vinak',
#   'external_url': 'https://api.spotify.com/v1/artists/1sKlyO3CCEvjeTN6Uck39S'},
#  {'artist_id': '2D66FABcMx1DcjVtrVAeHL',
#   'artist_name': 'Ashkan Kagan',
#   'external_url': 'https://api.spotify.com/v1/artists/2D66FABcMx1DcjVtrVAeHL'},
#  {'artist_id': '5SrqM7T6nTty4CPNn2WLcQ',
#   'artist_name': 'amiirsardaar',
#   'external_url': 'https://api.spotify.com/v1/artists/5SrqM7T6nTty4CPNn2WLcQ'},
#  {'artist_id': '7GI4WQWzCEZAIpjnhXkuwO',
#   'artist_name': 'Keyhan',
#   'external_url': 'https://api.spotify.com/v1/artists/7GI4WQWzCEZAIpjnhXkuwO'},
#  {'artist_id': '5xy1wyKK6gsbVSDEaIwMUy',
# ...

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
import pandas as pd
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id               name release_date  total_tracks  \
# 0  6kj47h4a5ptQiZRYsihT1Y  Missing Something   2024-08-02             8
# 1  5NhFIWsZFIOACwnsba6Opj             Belaad   2024-02-03             1
# 2  0Ft9mzyrJfw4XvitON7gMx   Doone Koochooloo   2024-04-02             1
# 3  7eQZeSPrFTIMVKKFCTjwO7    Shabhaye Tehran   2024-07-26             1
# 4  12zV0xfge3v6Fh6p0cxm4T               TNTV   2024-07-11             1
#
#                                                  url
# 0  https://open.spotify.com/album/6kj47h4a5ptQiZR...
# 1  https://open.spotify.com/album/5NhFIWsZFIOACwn...
# 2  https://open.spotify.com/album/0Ft9mzyrJfw4Xvi...
# 3  https://open.spotify.com/album/7eQZeSPrFTIMVKK...
# 4  https://open.spotify.com/album/12zV0xfge3v6Fh6...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      100 non-null    object
#  1   name          100 non-null    object
#  2   release_date  100 non-null    object
#  3   total_tracks  100 non-null    int64
#  4   url           100 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 4.0+ KB

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
artist_df.head()
# Out:
#                 artist_id    artist_name  \
# 0  2CPDwyokR2lgqu0yNGe2cU           Asal
# 1  45YMrIBH74j8e2wNlRSSdK  Hiphopologist
# 2  1sKlyO3CCEvjeTN6Uck39S          Vinak
# 3  2D66FABcMx1DcjVtrVAeHL   Ashkan Kagan
# 4  5SrqM7T6nTty4CPNn2WLcQ   amiirsardaar
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/2CPDwyokR2l...
# 1  https://api.spotify.com/v1/artists/45YMrIBH74j...
# 2  https://api.spotify.com/v1/artists/1sKlyO3CCEv...
# 3  https://api.spotify.com/v1/artists/2D66FABcMx1...
# 4  https://api.spotify.com/v1/artists/5SrqM7T6nTt...

# %%
#Song Dataframe
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df.head()
# Out:
#                   song_id         song_name  duration_ms  \
# 0  5Jdk6W2lxe4asVmoyjKgqr   Liars & Players       147272
# 1  6pIofVp1f3AEZTOkMkpEbp            Belaad       279719
# 2  0LwpkUKjZ8uITIHALnikIc  Doone Koochooloo       219666
# 3  0PxOXXpqWjJnsrSDbVChIx   Shabhaye Tehran       153281
# 4  0qVF3C6x2kxeNKE7BwZb2Q              TNTV       147321
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/5Jdk6W2lxe4asVm...          60
# 1  https://open.spotify.com/track/6pIofVp1f3AEZTO...          26
# 2  https://open.spotify.com/track/0LwpkUKjZ8uITIH...          12
# 3  https://open.spotify.com/track/0PxOXXpqWjJnsrS...          14
# 4  https://open.spotify.com/track/0qVF3C6x2kxeNKE...          27
#
#              song_added                album_id               artist_id
# 0  2024-12-26T14:47:47Z  6kj47h4a5ptQiZRYsihT1Y  2CPDwyokR2lgqu0yNGe2cU
# 1  2024-12-26T14:47:47Z  5NhFIWsZFIOACwnsba6Opj  45YMrIBH74j8e2wNlRSSdK
# ...

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
song_df['song_added'] =  pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      100 non-null    object
#  1   song_name    100 non-null    object
#  2   duration_ms  100 non-null    int64
#  3   url          100 non-null    object
#  4   popularity   100 non-null    int64
#  5   song_added   100 non-null    datetime64[ns, UTC]
#  6   album_id     100 non-null    object
#  7   artist_id    100 non-null    object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 6.4+ KB
